# %%
import pandas as pd

# %%
data = pd.read_csv("diabetes.csv")

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
treshold = 0.20

# %%
data.corr()[data.corr()["Outcome"] > treshold]
# Out:
#              Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin  \
# Pregnancies     1.000000  0.129459       0.141282      -0.081672 -0.073535
# Glucose         0.129459  1.000000       0.152590       0.057328  0.331357
# BMI             0.017683  0.221071       0.281805       0.392573  0.197859
# Age             0.544341  0.263514       0.239528      -0.113970 -0.042163
# Outcome         0.221898  0.466581       0.065068       0.074752  0.130548
#
#                   BMI  DiabetesPedigreeFunction       Age   Outcome
# Pregnancies  0.017683                 -0.033523  0.544341  0.221898
# Glucose      0.221071                  0.137337  0.263514  0.466581
# BMI          1.000000                  0.140647  0.036242  0.292695
# Age          0.036242                  0.033561  1.000000  0.238356
# Outcome      0.292695                  0.173844  0.238356  1.000000

# %% [markdown]
# ### En teoría esto significa que nuestras variables mas significativas son:
# - Embarasos
# - Glucosa
# - BMI
# - Edad

# %%
dataReduced = data[["Pregnancies","Glucose","BMI","Age"]]
dataReduced
# Out:
#      Pregnancies  Glucose   BMI  Age
# 0              6      148  33.6   50
# 1              1       85  26.6   31
# 2              8      183  23.3   32
# 3              1       89  28.1   21
# 4              0      137  43.1   33
# 5              5      116  25.6   30
# 6              3       78  31.0   26
# 7             10      115  35.3   29
# 8              2      197  30.5   53
# 9              8      125   0.0   54
# 10             4      110  37.6   30
# 11            10      168  38.0   34
# 12            10      139  27.1   57
# 13             1      189  30.1   59
# 14             5      166  25.8   51
# 15             7      100  30.0   32
# 16             0      118  45.8   31
# 17             7      107  29.6   31
# 18             1      103  43.3   33
# 19             1      115  34.6   32
# 20             3      126  39.3   27
# 21             8       99  35.4   50
# 22             7      196  39.8   41
# 23             9      119  29.0   29
# ...

# %%
# %matplotlib inline

# %%
data.groupby("Outcome").hist()
# Out:
# Outcome
# 0    [[Axes(0.125,0.670278;0.215278x0.209722), Axes...
# 1    [[Axes(0.125,0.670278;0.215278x0.209722), Axes...
# dtype: object

# %%
data.hist(by="Outcome")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-8b5c3c26d9b7> in <module>()
# ----> 1 data.groupby("Outcome").hist(by="Outcome")
#
# /Users/andreselizondo/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in wrapper(*args, **kwargs)
#     593             # exception below
#     594             if name in _plotting_methods:
# --> 595                 return self.apply(curried)
#     596
#     597             try:
#
# /Users/andreselizondo/anaconda/lib/python3.6/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     714         # ignore SettingWithCopy here in case the user mutates
#     715         with option_context('mode.chained_assignment', None):
# --> 716             return self._python_apply_general(f)
#     717
#     718     def _python_apply_general(self, f):
#
# ...

# %%
?? data.hist()
